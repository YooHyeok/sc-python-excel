# %%
# shutil 사용

# 사전작업 - 테라/카스 폴더가 없을 때만 만들기
import os

path = r'C:\Users\dq\diquest\study\inflearn\startcoding-python-excel\02.폴더및파일관리\테라'
if not os.path.exists(path):
  os.mkdir(path)
path = r'C:\Users\dq\diquest\study\inflearn\startcoding-python-excel\02.폴더및파일관리\카스'
if not os.path.exists(path):
  os.mkdir(path)

# %%
# 폴더 이동 - move(a, b)
import shutil
shutil.move('../카스', './') # 현재 디렉토리의 상위에 있는 카스 디렉토리를 현재 디렉토리로 이동
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[3], line 3
#       1 import shutil
# ----> 3 shutil.move('../카스', './') # 폴더 이동 - 현재 디렉토리의 상위에 있는 카스 디렉토리를 현재 디렉토리로 이동
#
# File c:\Python313\Lib\shutil.py:854, in move(src, dst, copy_function)
#     851     real_dst = os.path.join(dst, _basename(src))
#     853     if os.path.exists(real_dst):
# --> 854         raise Error("Destination path '%s' already exists" % real_dst)
#     855 try:
#     856     os.rename(src, real_dst)
#
# Error: Destination path './카스' already exists

# %%
shutil.move('일기.txt', '카스')
# Out:
# '카스\\일기.txt'

# %%
shutil.move('일기1.txt', '카스')
# Out:
# '카스\\일기1.txt'

# %%
# 파일복사 - copy(a, b)
shutil.copy('카스/일기.txt', '테라') # 카스/일기.txt를 테라 디렉토리로 복사
# Out:
# '테라\\일기.txt'
